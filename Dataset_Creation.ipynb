# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import statsmodels.formula.api as smf
import seaborn as sns
from tqdm import tqdm
import zipfile
from collections import Counter

# %%
df = pd.read_parquet('links.parquet')
df
# Out:
#                                                raw_data
# 0     <!DOCTYPE html>\n<html class="client-nojs" lan...
# 1     <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2     <!DOCTYPE html>\n<html class="client-nojs" lan...
# 3     <!DOCTYPE html>\n<html class="client-nojs" lan...
# 4     <!DOCTYPE html>\n<html class="client-nojs" lan...
# ...                                                 ...
# 3674  <!DOCTYPE html>\n<html class="client-nojs" lan...
# 3675  <!DOCTYPE html>\n<html class="client-nojs" lan...
# 3676  <!DOCTYPE html>\n<html class="client-nojs" lan...
# 3677  <!DOCTYPE html>\n<html class="client-nojs" lan...
# 3678  <!DOCTYPE html>\n<html class="client-nojs" lan...
#
# [3679 rows x 1 columns]

# %%
url = 'https://awoiaf.westeros.org/index.php/List_of_characters'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'}
r = requests.get(url, headers = headers)
r.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(r.text)
text = soup.find_all('div', class_='mw-parser-output')
links = []
for elem in text[0].find_all('ul')[1:]:
    for name in elem.find_all('li'):
        links.append(name.a.get('href'))
links
# Out:
# ['/index.php/A_certain_man',
#  '/index.php/Abelar_Hightower',
#  '/index.php/Abelon',
#  '/index.php/Addam_of_Duskendale',
#  '/index.php/Addam_Frey',
#  '/index.php/Addam_Hightower',
#  '/index.php/Addam_Marbrand',
#  '/index.php/Addam_Osgrey',
#  '/index.php/Addam_Rivers',
#  '/index.php/Addam_Velaryon',
#  '/index.php/Addam_Whitehead',
#  '/index.php/Addison_Hill',
#  '/index.php/Adrack_Humble',
#  '/index.php/Adrian_Redfort',
#  '/index.php/Adrian_Tarbeck',
#  '/index.php/Adrian_Thorne',
#  '/index.php/Aegon_Ambrose',
#  '/index.php/Aegon_Blackfyre',
#  '/index.php/Aegon_Frey_(son_of_Stevron)',
#  '/index.php/Aegon_Frey_(son_of_Aenys)',
#  '/index.php/Aegon_I_Targaryen',
#  '/index.php/Aegon_II_Targaryen',
#  '/index.php/Aegon_III_Targaryen',
#  '/index.php/Aegon_IV_Targaryen',
#  '/index.php/Aegon_V_Targaryen',
#  '/index.php/Aegon_Targaryen_(son_of_Gaemon)',
#  '/index.php/Aegon_Targaryen_(son_of_Aenys_I)',
#  '/index.php/Aegon_Targaryen_(son_of_Jaehaerys_I)',
#  '/index.php/Aegon_Targaryen_(son_of_Baelon)',
#  '/index.php/Aegon_Targaryen_(son_of_Aerys_II)',
#  '/index.php/Aegon_Targaryen_(son_of_Rhaegar)',
#  '/index.php/Aegor_Rivers',
#  '/index.php/Aelinor_Penrose',
#  '/index.php/Aelor_Targaryen',
#  '/index.php/Aelora_Targaryen',
#  '/index.php/Aelyx_Targaryen',
#  '/index.php/Aemma_Arryn',
#  '/index.php/Aemon_Blackfyre',
#  '/index.php/Aemon_Costayne',
#  '/index.php/Aemon_Estermont',
#  '/index.php/Aemon_Rivers',
#  '/index.php/Aemon_Steelsong',
#  '/index.php/Aemon_Targaryen_(son_of_Jaehaerys_I)',
#  '/index.php/Aemon_Targaryen_(son_of_Viserys_II)',
#  '/index.php/Aemon_Targaryen_(son_of_Maekar_I)',
#  '/index.php/Aemond_Targaryen',
#  '/index.php/Aenys_Blackfyre',
#  '/index.php/Aenys_Frey',
#  '/index.php/Aenys_I_Targaryen',
#  '/index.php/Aerea_Targaryen',
#  '/index.php/Aerion_Targaryen',
#  '/index.php/Aerion_Targaryen_(son_of_Daemion)',
#  '/index.php/Aeron_Greyjoy',
#  '/index.php/Aerys_Targaryen_(son_of_Aegon)',
#  '/index.php/Aerys_I_Targaryen',
#  '/index.php/Aerys_II_Targaryen',
#  '/index.php/Aerys_II_Targaryen%27s_last_mistress',
#  '/index.php/Aethan',
#  '/index.php/Aethan_Velaryon',
#  '/index.php/Aethelmure',
#  '/index.php/Aggar',
#  '/index.php/Aggo',
#  '/index.php/Aglantine',
#  '/index.php/Agnes_Blackwood',
#  '/index.php/Agramore_Cobb',
#  '/index.php/Agrivane',
#  '/index.php/Aladale_Wynch',
#  '/index.php/Aladore_Florent',
#  '/index.php/Alan_o%27_the_Oak',
#  '/index.php/Alan_of_Rosby',
#  '/index.php/Alan_Beesbury',
#  '/index.php/Alan_Tarly',
#  '/index.php/Alannys_Harlaw',
#  '/index.php/Alaric_of_Eysen',
#  '/index.php/Alaric_Stark',
#  '/index.php/Alarra_Massey',
#  '/index.php/Alarra_Stark',
#  '/index.php/Alastor_Reyne',
#  '/index.php/Alayaya',
#  '/index.php/Alayne_Baelish',
#  '/index.php/Alayne_Royce',
#  '/index.php/Albar_Royce',
#  '/index.php/Albett',
#  '/index.php/Albin_Manwoody',
#  '/index.php/Albin_Massey',
#  '/index.php/Alchemist',
#  '/index.php/Alebelly',
#  '/index.php/Alec_Hunter',
#  '/index.php/Alekyne_Florent',
#  '/index.php/Alequo_Adarys',
#  '/index.php/Alerie_Hightower',
#  '/index.php/Alesander_Frey',
#  '/index.php/Alesander_Staedmon',
#  '/index.php/Alesandor_Torrent',
#  '/index.php/Alester_II_Arryn',
#  '/index.php/Alester_Florent',
#  '/index.php/Alester_Norcross',
#  '/index.php/Alester_Oakheart',
#  '/index.php/Alester_Wynch',
#  '/index.php/Alf_of_Runnymudd',
#  '/index.php/Alfador',
#  '/index.php/Alford',
#  '/index.php/Alfred_Broome',
#  '/index.php/Alfyn_Crowkiller',
#  '/index.php/Alfyn_(septon)',
#  '/index.php/Alia',
#  '/index.php/Aliandra_Martell',
#  '/index.php/Alicent_Hightower',
#  '/index.php/Alios_Qhaedar',
#  '/index.php/All-for-Joffrey',
#  '/index.php/Alla_Tyrell',
#  '/index.php/Allaquo',
#  '/index.php/Allar',
#  '/index.php/Allar_Deem',
#  '/index.php/Allard_Royce',
#  '/index.php/Allard_Seaworth',
#  '/index.php/Alleras',
#  '/index.php/Alliser_Thorne',
#  '/index.php/Allyria_Dayne',
#  '/index.php/Alton_Butterwell',
#  '/index.php/Alton_Celtigar',
#  '/index.php/Alton_Greyjoy',
#  '/index.php/Alvyn_Sharp',
#  '/index.php/Alyce',
#  '/index.php/Alyce_Graceford',
#  '/index.php/Alyn',
#  '/index.php/Red_Alyn_of_the_Rosewood',
#  '/index.php/Sour_Alyn',
#  '/index.php/Alyn_Ambrose',
#  '/index.php/Alyn_Ashford',
#  '/index.php/Ardrian_Celtigar',
#  '/index.php/Aregelle_Stark',
#  '/index.php/Areo_Hotah',
#  '/index.php/Argella_Durrandon',
#  '/index.php/Argilac_Durrandon',
#  '/index.php/Argos_Sevenstar',
#  '/index.php/Argoth_Stone-Skin',
#  '/index.php/Argrave_the_Defiant',
#  '/index.php/Arianne_Martell',
#  '/index.php/Arianne_Tarth',
#  '/index.php/Arlan_of_Pennytree',
#  '/index.php/Arlan_I_Durrandon',
#  '/index.php/Arlan_III_Durrandon',
#  '/index.php/Arlan_V_Durrandon',
#  '/index.php/Armen',
#  '/index.php/Armen_Peake',
#  '/index.php/Armistead_Vance',
#  '/index.php/Armond_Caswell',
#  '/index.php/Armond_Connington',
#  '/index.php/Arnel',
#  '/index.php/Arneld',
#  '/index.php/Arnell',
#  '/index.php/Arnold_Arryn',
#  '/index.php/Arnolf_Karstark',
#  '/index.php/Aron_Santagar',
#  '/index.php/Arra_Norrey',
#  '/index.php/Arrana_Stark',
#  '/index.php/Arrec_Durrandon',
#  '/index.php/Arron',
#  '/index.php/Arron_Qorgyle',
#  '/index.php/Arryk_(guard)',
#  '/index.php/Arryk_Cargyll',
#  '/index.php/Lord_Arryn_(father_of_Jeyne)',
#  '/index.php/Arsa_Stark',
#  '/index.php/Arson',
#  '/index.php/Arstan_Selmy',
#  '/index.php/Arthor_Celtigar',
#  '/index.php/Arthor_Karstark',
#  '/index.php/Arthor_Oakheart',
#  '/index.php/Arthur_Ambrose',
#  '/index.php/Arthur_Dayne',
#  '/index.php/Arthur_Goodbrother',
#  '/index.php/Artos_the_Strong',
#  '/index.php/Artos_Flint',
#  '/index.php/Artos_Stark',
#  '/index.php/Artys_I_Arryn',
#  '/index.php/Arwen_Upcliff',
#  '/index.php/Arwood_Frey',
#  '/index.php/Arwyn_Frey',
#  '/index.php/Arwyn_Oakheart',
#  '/index.php/Arya_Flint',
#  '/index.php/Arya_Stark',
#  '/index.php/Arys_Oakheart',
#  '/index.php/Ash',
#  '/index.php/Asha_Greyjoy',
#  '/index.php/Ashara_Dayne',
#  '/index.php/Lord_Ashford',
#  '/index.php/Assadora_of_Ibben',
#  '/index.php/Aubrey_Ambrose',
#  '/index.php/Aubrey_Crakehall',
#  '/index.php/Aurane_Waters',
#  '/index.php/Aurion',
#  '/index.php/Axel_Tully',
#  '/index.php/Axell_Florent',
#  '/index.php/Ayrmidon',
#  '/index.php/Azor_Ahai',
#  '/index.php/Azzak_zo_Ghazeen',
#  '/index.php/Bael_the_Bard',
#  '/index.php/Baelish_(hedge_knight)',
#  '/index.php/Baelish_(lord)',
#  '/index.php/Baelish_(sellsword)',
#  '/index.php/Baela_Targaryen',
#  '/index.php/Baelon_Targaryen_(son_of_Aerys)',
#  '/index.php/Baelon_Targaryen_(son_of_Viserys_I)',
#  '/index.php/Baelor_Blacktyde',
#  '/index.php/Baelor_Hightower',
#  '/index.php/Baelor_I_Targaryen',
#  '/index.php/Baelor_Targaryen_(son_of_Daeron_II)',
#  '/index.php/Black_Balaq',
#  '/index.php/Balder',
#  '/index.php/Baldric_I_Durrandon',
#  '/index.php/Daemon_Targaryen',
#  '/index.php/Daemon_Velaryon',
#  '/index.php/Daemon_Velaryon_(son_of_Aethan)',
#  '/index.php/Daena_(mummer)',
#  '/index.php/Daena_Targaryen',
#  '/index.php/Daenaera_Velaryon',
#  '/index.php/Daenerys_Targaryen_(daughter_of_Jaehaerys_I)',
#  '/index.php/Daenerys_Targaryen_(daughter_of_Aegon_IV)',
#  '/index.php/Daenerys_Targaryen',
#  '/index.php/Daenora_Targaryen',
#  '/index.php/Daeron_I_Targaryen',
#  '/index.php/Daeron_II_Targaryen',
#  '/index.php/Daeron_Targaryen_(son_of_Viserys_I)',
#  '/index.php/Daeron_Targaryen_(son_of_Maekar_I)',
#  '/index.php/Daeron_Targaryen_(son_of_Aegon_V)',
#  '/index.php/Daeron_Targaryen_(son_of_Aerys_II)',
#  '/index.php/Daeron_Vaith',
#  '/index.php/Daeron_Velaryon',
#  '/index.php/Daeryssa',
#  '/index.php/Dafyn_Vance',
#  '/index.php/Dagmer',
#  '/index.php/Dagon_Codd',
#  '/index.php/Dagon_Ironmaker',
#  '/index.php/Dagon_Greyjoy',
#  '/index.php/Dagon_Greyjoy_(Drunkard)',
#  '/index.php/Dagos_Manwoody',
#  '/index.php/Dake',
#  '/index.php/Dake_(Guard)',
#  '/index.php/Dalbridge',
#  '/index.php/Droopeye_Dale',
#  '/index.php/Dale_Drumm',
#  '/index.php/Dale_Seaworth',
#  '/index.php/Dalla',
#  '/index.php/Dalla_(Dragonstone)',
#  '/index.php/Dalton_Greyjoy',
#  '/index.php/Damion_Lannister',
#  '/index.php/Damon_Dance-for-Me',
#  '/index.php/Damon_Darry',
#  '/index.php/Damon_Hightower',
#  '/index.php/Damon_Lannister_(lord)',
#  '/index.php/Damon_Lannister_(son_of_Jason)',
#  '/index.php/Damon_Marbrand',
#  '/index.php/Damon_Morrigen',
#  '/index.php/Damon_Paege',
#  '/index.php/Damon_Shett',
#  '/index.php/Damon_Teague',
#  '/index.php/Damon_Vypren',
#  '/index.php/Dan',
#  '/index.php/Dancy',
#  '/index.php/Danelle_Lothston',
#  '/index.php/Dannel',
#  '/index.php/Danny_Flint',
#  '/index.php/Danos_Slynt',
#  '/index.php/Danwell_Frey',
#  '/index.php/Dareon',
#  '/index.php/Darke_(Seven_Swords)',
#  '/index.php/Lord_Darklyn_(father_of_Jonquil_Darke)',
#  '/index.php/Darla_Deddings',
#  '/index.php/Darlessa_Marbrand',
#  '/index.php/Darnold_Darry',
#  '/index.php/Darnold_Arryn',
#  '/index.php/Lord_Darry_(Dance)',
#  '/index.php/Lord_Darry_(father_of_Raymun)',
#  '/index.php/Daryn_Hornwood',
#  '/index.php/Daughter_of_the_captain_of_the_Myraham',
#  '/index.php/Daughter_of_the_Dusk',
#  '/index.php/Daven_Lannister',
#  '/index.php/Davos_the_Dragonslayer',
#  '/index.php/Davos_Baratheon',
#  '/index.php/Davos_Darklyn',
#  '/index.php/Davos_Dayne',
#  '/index.php/Davos_Deddings',
#  '/index.php/Davos_Seaworth',
#  '/index.php/Deana_Hardyng',
#  '/index.php/Lady_Deddings',
#  '/index.php/Lord_Deddings',
#  '/index.php/Del',
#  '/index.php/Delena_Florent',
#  '/index.php/Della_Frey',
#  '/index.php/Dellono',
#  '/index.php/Delonne_Allyrion',
#  '/index.php/Delp',
#  '/index.php/Demon_of_Darry',
#  '/index.php/Denestan',
#  '/index.php/Dennet',
#  '/index.php/Dennis_Plumm',
#  '/index.php/Dennis_the_Lame',
#  '/index.php/Dennis_Whitfield',
#  '/index.php/Denyo_Terys',
#  '/index.php/Silver_Denys',
#  '/index.php/Denys_Arryn',
#  '/index.php/Denys_Darklyn',
#  '/index.php/Denys_Drumm',
#  '/index.php/Denys_Harte',
#  '/index.php/Denys_Mallister',
#  '/index.php/Denys_Oakheart',
#  '/index.php/Denys_Redwyne',
#  '/index.php/Denys_Snow',
#  '/index.php/Denys_Strong',
#  '/index.php/Denys_Swann',
#  '/index.php/Denys_Woodwright',
#  '/index.php/Denyse_Hightower',
#  '/index.php/Denzo_D%27han',
#  '/index.php/Deremond',
#  '/index.php/Deria_Martell',
#  '/index.php/Dermot_of_the_Rainwood',
#  '/index.php/Derrick_Darry',
#  '/index.php/Derrick_Fossoway',
#  '/index.php/Desmera_Redwyne',
#  '/index.php/Desmond_(Grand_Maester)',
#  '/index.php/Desmond',
#  '/index.php/Desmond_Darry',
#  '/index.php/Desmond_Grell',
#  '/index.php/Desmond_Mallister',
#  '/index.php/Desmond_Redwyne',
#  '/index.php/Devan_Seaworth',
#  '/index.php/Devyn_Sealskinner',
#  '/index.php/Deziel_Dalt',
#  '/index.php/Dhako',
#  '/index.php/Dhazzar',
#  '/index.php/Beardless_Dick',
#  '/index.php/Fletcher_Dick',
#  '/index.php/Yellow_Dick',
#  '/index.php/Dick_Bean',
#  '/index.php/Dick_Cole',
#  '/index.php/Dick_Crabb',
#  '/index.php/Dick_Follard',
#  '/index.php/Dick_Straw',
#  '/index.php/Dickon_Flowers',
#  '/index.php/Dickon_Frey',
#  '/index.php/Dickon_Manwoody',
#  '/index.php/Dickon_Morrigen',
#  '/index.php/Dickon_Tarly',
#  '/index.php/Dirk',
#  '/index.php/Dobber',
#  '/index.php/Dogkiller',
#  '/index.php/Dolf',
#  '/index.php/Domeric_Bolton',
#  '/index.php/Donal_Noye',
#  '/index.php/Lord_Dondarrion_(father_of_Simon)',
#  '/index.php/Lord_Dondarrion_(father_of_Manfred)',
#  '/index.php/Donel_Greyjoy',
#  '/index.php/Donella_Hornwood',
#  '/index.php/Doniphos_Paenymion',
#  '/index.php/Donnel_Arryn',
#  '/index.php/Donnel_Drumm',
#  '/index.php/Donnel_Flint',
#  '/index.php/Donnel_Haigh',
#  '/index.php/Donnel_Hightower',
#  '/index.php/Donnel_Hill',
#  '/index.php/Donnel_Locke',
#  '/index.php/Donnel_of_Duskendale',
#  '/index.php/Donnel_Swann',
#  '/index.php/Donnel_Waynwood',
#  '/index.php/Donnis',
#  '/index.php/Donnor_Stark',
#  '/index.php/Donnor_Saltcliffe',
#  '/index.php/Dontos_Hollard',
#  '/index.php/Donyse',
#  '/index.php/Doran_Martell',
#  '/index.php/Dorcas',
#  '/index.php/Dorden_the_Dour',
#  '/index.php/Dorea_Sand',
#  '/index.php/Doreah',
#  '/index.php/Dorian_Hightower',
#  '/index.php/Dormund',
#  '/index.php/Dorna_Swyft',
#  '/index.php/Dornish_Dilly',
#  '/index.php/Doro_Golathis',
#  '/index.php/Dorren_Stark',
#  '/index.php/Doshi',
#  '/index.php/Blind_Doss',
#  '/index.php/Drako_Rogare',
#  '/index.php/Draper%27s_wife',
#  '/index.php/Draqaz',
#  '/index.php/Drazenko_Rogare',
#  '/index.php/Drennan',
#  '/index.php/Drinkwater_twins',
#  '/index.php/Drogo',
#  '/index.php/Drox_the_Corpse-Maker',
#  '/index.php/Drunken_Daughter',
#  '/index.php/Druselka',
#  '/index.php/Dryn',
#  '/index.php/Dudley',
#  '/index.php/Dunaver',
#  '/index.php/Duncan_the_Tall',
#  '/index.php/Duncan_Liddle',
#  '/index.php/Duncan_Strong',
#  '/index.php/Duncan_Targaryen',
#  '/index.php/Dunsen',
#  '/index.php/Dunstan_Drumm',
#  '/index.php/Dunstan_Pryor',
#  '/index.php/Duram_Bar_Emmon',
#  '/index.php/Duran',
#  '/index.php/Durran',
#  '/index.php/Durran_II_Durrandon',
#  '/index.php/Durran_Durrandon_(Bronze-Axe)',
#  '/index.php/Durran_Durrandon_(the_Dour)',
#  '/index.php/Durran_Durrandon_(the_Ravenfriend)',
#  '/index.php/Durran_Durrandon_(the_Young)',
#  '/index.php/Durran_Durrandon_(the_Fair)',
#  '/index.php/Durran_X_Durrandon',
#  '/index.php/Durran_XI_Durrandon',
#  '/index.php/Durran_XXI_Durrandon',
#  '/index.php/Durran_XXIV_Durrandon',
#  '/index.php/Durran_the_Third',
#  '/index.php/Durwald_I_Durrandon',
#  '/index.php/Dusky_woman',
#  '/index.php/Dyah',
#  '/index.php/Dyanna_Dayne',
#  '/index.php/Dykk_Harlaw',
#  '/index.php/Dywen',
#  '/index.php/Dywen_Shell',
#  '/index.php/Earl_Harlaw',
#  '/index.php/Easy',
#  '/index.php/Ebben',
#  '/index.php/Ebrose',
#  '/index.php/Eddara_Tallhart',
#  '/index.php/Eddard_Karstark',
#  '/index.php/Eddard_Stark',
#  '/index.php/Edderion_Stark',
#  '/index.php/Eddison_Peake_(the_Elder)',
#  '/index.php/Eddison_Peake_(the_Younger)',
#  '/index.php/Eddison_Tollett',
#  '/index.php/Eden_Risley',
#  '/index.php/Edgar_Yronwood',
#  '/index.php/Edgar_Sloane',
#  '/index.php/Edgerran',
#  '/index.php/Edgerran_Oakheart',
#  '/index.php/Edmund_Ambrose',
#  '/index.php/Edmund_Blackwood',
#  '/index.php/Edmund_Breakstone',
#  '/index.php/Edmund_Gardener',
#  '/index.php/Edmund_Warrick',
#  '/index.php/Edmund_Waxley',
#  '/index.php/Edmure_Tully',
#  '/index.php/Edmure_Tully_(father_of_Axel)',
#  '/index.php/Edmyn_Tully',
#  '/index.php/Edric_Dayne',
#  '/index.php/Edric_Stark',
#  '/index.php/Edric_Stark_(son_of_Cregan)',
#  '/index.php/Edric_Storm',
#  '/index.php/Edrick_Stark',
#  '/index.php/Edwell_Celtigar',
#  '/index.php/Edwyd_Fossoway',
#  '/index.php/Edwyle_Stark',
#  '/index.php/Edwyn_Frey',
#  '/index.php/Edwyn_Osgrey',
#  '/index.php/Edwyn_Stark',
#  '/index.php/Edwyn_Tarth',
#  '/index.php/Edyth',
#  '/index.php/Egbert',
#  '/index.php/Eggon',
#  '/index.php/Eglantine',
#  '/index.php/Egon_Emeros',
#  '/index.php/Eladon_Goldenhair',
#  '/index.php/Elaena_Targaryen',
#  '/index.php/Elaena_Targaryen_(daughter_of_Gaemon)',
#  '/index.php/Elbert_Arryn',
#  '/index.php/Elder_Brother_(Quiet_Isle)',
#  '/index.php/Elderly_man',
#  '/index.php/Eldiss',
#  '/index.php/Eldon_Estermont',
#  '/index.php/Eldred_Codd',
#  '/index.php/Eldric_Arryn',
#  '/index.php/Eleanor_Mooton',
#  '/index.php/Elenda_Caron',
#  '/index.php/Elenei',
#  '/index.php/Lord_Elesham',
#  '/index.php/Eleyna_Westerling',
#  '/index.php/Elia_Martell',
#  '/index.php/Elia_Sand',
#  '/index.php/Elinda_Massey',
#  '/index.php/Elinor_Costayne',
#  '/index.php/Elinor_Massey',
#  '/index.php/Elinor_Tyrell',
#  '/index.php/Elissa_Farman',
#  '/index.php/Elkin',
#  '/index.php/Ella_Broome',
#  '/index.php/Ella_Lannister',
#  '/index.php/Ellard_Stark',
#  '/index.php/Ellard_Crane',
#  '/index.php/Ellaria_Sand',
#  '/index.php/Ellendor',
#  '/index.php/Ellery_Vance',
#  ...]

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'}
links_csv = []
for link in tqdm(links):
    url = 'https://awoiaf.westeros.org' + link
    r = requests.get(url, headers = headers)
    if r.status_code == 200:
        links_csv.append({'raw_data': r.text})
    else:
        print('error: ', r.status_code)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 3679/3679 [1:31:01<00:00,  1.48s/it]

# %%
df_links = pd.DataFrame(links_csv)
df_links
# Out:
#                                                raw_data
# 0     <!DOCTYPE html>\n<html class="client-nojs" lan...
# 1     <!DOCTYPE html>\n<html class="client-nojs" lan...
# 2     <!DOCTYPE html>\n<html class="client-nojs" lan...
# 3     <!DOCTYPE html>\n<html class="client-nojs" lan...
# 4     <!DOCTYPE html>\n<html class="client-nojs" lan...
# ...                                                 ...
# 3674  <!DOCTYPE html>\n<html class="client-nojs" lan...
# 3675  <!DOCTYPE html>\n<html class="client-nojs" lan...
# 3676  <!DOCTYPE html>\n<html class="client-nojs" lan...
# 3677  <!DOCTYPE html>\n<html class="client-nojs" lan...
# 3678  <!DOCTYPE html>\n<html class="client-nojs" lan...
#
# [3679 rows x 1 columns]

# %%
df_links.to_parquet('links.parquet')

# %% [markdown]
# ### Surname dataset

# %%
import os
import time
from tqdm import tqdm
surnames = []
for index, row in tqdm(df_links.iterrows()):
    html = row['raw_data']
    soup = BeautifulSoup(html)
    firstName = soup.find_all('h1', class_='firstHeading page-header')[0].span.text
    infobox = soup.find_all('table', class_ = 'infobox')
    names = [] 
    if infobox:
        list = infobox[0].find_all('tr')                   
        for elem in list:
            if elem.th:
                if elem.th.text == 'Aliases':
                    list = elem.find_all('li')
                    for name in list:
                        surname = re.findall(r'^(?:\d+,\d+)?[^[]+',name.text)
                        names.append(surname[0])
                        
                    break
                if elem.th.text == 'Alias': 
                    name = elem.td.text
                    surname = re.findall(r'^(?:\d+,\d+)?[^[]+',name)
                    names.append(surname[0])
                        
                    break
    surnames.append({'name': firstName, 'surname': names})
# Out:
# 3679it [01:18, 46.80it/s]

# %%
df_surname = pd.DataFrame(surnames)
df_surname
# Out:
#                      name                                            surname
# 0           A certain man                                                 []
# 1        Abelar Hightower                                                 []
# 2                  Abelon                                                 []
# 3     Addam of Duskendale                            [\nAddam of Duskendale]
# 4              Addam Frey                                                 []
# ...                   ...                                                ...
# 3674      Zharaq zo Loraq                                  [\nThe Liberator]
# 3675                 Zhea  [Zhea the Barren, Zhea Zorseface, Zhea the Cruel]
# 3676       Zhoe Blanetree                                                 []
# 3677             Zia Frey                                                 []
# 3678                Zollo                                  [\nZollo the Fat]
#
# [3679 rows x 2 columns]

# %%
count = Counter(df_surname.name.values)
most_occurences = count.most_common()
repeat = []
for element, occurrences in most_occurences:
    if occurrences > 1:
        repeat.append(element)

# %%
repeat
# Out:
# ['Beardless Dick',
#  'Canker Jeyne',
#  'Clubfoot Karl',
#  'Corwyn Corbray',
#  'Fearless Ithoke',
#  'List of characters created for Game of Thrones',
#  'High Septon (stonemason)',
#  'Jack Bulwer',
#  'Lord of Bones',
#  'Paxter Redwyne',
#  'Poxy Tym',
#  'Red Rolfe',
#  'Robyn Rhysling']

# %%
for elem in repeat:
    df_surname = df_surname.drop(index=df_surname[df_surname.name == elem].index[1])

# %%
df_surname.to_parquet('surnames.parquet')

# %%
test = pd.read_parquet('surnames.parquet')
test
# Out:
#                      name                                            surname
# 0           A certain man                                                 []
# 1        Abelar Hightower                                                 []
# 2                  Abelon                                                 []
# 3     Addam of Duskendale                            [\nAddam of Duskendale]
# 4              Addam Frey                                                 []
# ...                   ...                                                ...
# 3674      Zharaq zo Loraq                                  [\nThe Liberator]
# 3675                 Zhea  [Zhea the Barren, Zhea Zorseface, Zhea the Cruel]
# 3676       Zhoe Blanetree                                                 []
# 3677             Zia Frey                                                 []
# 3678                Zollo                                  [\nZollo the Fat]
#
# [3666 rows x 2 columns]

# %% [markdown]
# ### Books dataset

# %%
import os
import time
from tqdm import tqdm
books = []

for index, row in tqdm(df_links.iterrows()):
    html = row['raw_data']
    soup = BeautifulSoup(html)
    firstName = soup.find_all('h1', class_='firstHeading page-header')[0].span.text
    infobox = soup.find_all('table', class_ = 'infobox')
    books_appearance = []
    books_mentioned = []
    books_POV = []
    if infobox:
        list = infobox[0].find_all('tr')                   
        for elem in list:
            if elem.th: # appears, mentioned, POV
                if elem.th.text == 'Books':
                    list = elem.find_all('li')
                    for book in list:
                        if 'mentioned' in book.text:
                            books_mentioned.append(book.a.text)

                        if 'appears' in book.text:
                            books_appearance.append(book.a.text)

                        if 'POV' in book.text:
                            books_POV.append(book.a.text)
                        
                    break
                if elem.th.text == 'Book': 
                    if 'mentioned' in elem.td.text:
                            books_mentioned.append(elem.a.text)

                    if 'appears' in elem.td.text:
                        books_appearance.append(elem.a.text)

                    if 'POV' in elem.td.text:
                        books_POV.append(elem.a.text)
                        
                    break
    books.append({'name': firstName, 'books_mentioned': books_mentioned, 'books_appearance': books_appearance, 'books_POV': books_POV})
# Out:
# 3679it [01:26, 42.55it/s]

# %%
df_books = pd.DataFrame(books)
df_books
# Out:
#                      name            books_mentioned      books_appearance  \
# 0           A certain man         [A Clash of Kings]                    []
# 1        Abelar Hightower                         []    [The Hedge Knight]
# 2                  Abelon           [Fire and Blood]                    []
# 3     Addam of Duskendale  [The World of Ice & Fire]                    []
# 4              Addam Frey                         []  [The Mystery Knight]
# ...                   ...                        ...                   ...
# 3674      Zharaq zo Loraq     [A Dance with Dragons]                    []
# 3675                 Zhea  [The World of Ice & Fire]                    []
# 3676       Zhoe Blanetree                         []                    []
# 3677             Zia Frey                         []                    []
# 3678                Zollo        [A Feast for Crows]   [A Storm of Swords]
#
#      books_POV
# 0           []
# 1           []
# 2           []
# 3           []
# 4           []
# ...        ...
# 3674        []
# 3675        []
# 3676        []
# 3677        []
# 3678        []
#
# [3679 rows x 4 columns]

# %%
count = Counter(df_books.name.values)
most_occurences = count.most_common()
repeat = []
for element, occurrences in most_occurences:
    if occurrences > 1:
        repeat.append(element)

# %%
for elem in repeat:
    df_books = df_books.drop(index=df_books[df_books.name == elem].index[1])

# %%
df_books.to_parquet('books.parquet')

# %% [markdown]
# ### Text length, rank & infobox name dataset

# %%
infos = []

for index, row in tqdm(df_links.iterrows()):
    html = row['raw_data']
    soup = BeautifulSoup(html)
    firstName = soup.find_all('h1', class_='firstHeading page-header')[0].span.text
    infobox = soup.find_all('table', class_ = 'infobox')
    text_container = soup.find_all('div', class_= 'mw-parser-output')
    
    # find text length
    texts = text_container[0].find_all("p")
    text = "".join(i.text for i in texts)
    text = re.sub(r"\[\d+\]", "", text)
    text_len = len(text)


    #find rank
    page_rank = 0
    a_list = soup.find_all('a')
    for a in a_list:
        if a.get('href') in links:
           page_rank += 1 

    # find infobox name
    if infobox:
        table = infobox[0].find_all('table')
        if table:
            td = table[0].find_all('td')
            span = td[1].find("span")
            if span:
                tmp = span.text.strip()
                span.decompose()
                infobox_name = tmp + " " + td[1].text
            else:
                infobox_name = td[1].text
        else:
            infobox_name = infobox[0].find_all('th')[0].text
    else:
        infobox_name = ''
    # Create the dictionnary
    infos.append({'name': firstName, 'infobox_name': infobox_name, 'text_length': text_len, 'rank': page_rank})
# Out:
# 3679it [01:42, 35.72it/s]

# %%
df_infos = pd.DataFrame(infos)
df_infos
# Out:
#                      name          infobox_name  text_length  rank
# 0           A certain man         A certain man         1254     3
# 1        Abelar Hightower  Ser Abelar Hightower          508     3
# 2                  Abelon    Archmaester Abelon          102     0
# 3     Addam of Duskendale   Addam of Duskendale          175     0
# 4              Addam Frey        Ser Addam Frey          586    14
# ...                   ...                   ...          ...   ...
# 3674      Zharaq zo Loraq       Zharaq zo Loraq          109     1
# 3675                 Zhea                  Zhea         1110     1
# 3676       Zhoe Blanetree        Zhoe Blanetree          269    21
# 3677             Zia Frey              Zia Frey           64    16
# 3678                Zollo         the Fat Zollo         1035     7
#
# [3679 rows x 4 columns]

# %%
count = Counter(df_infos.name.values)
most_occurences = count.most_common()
repeat = []
for element, occurrences in most_occurences:
    if occurrences > 1:
        repeat.append(element)

# %%
for elem in repeat:
    df_infos = df_infos.drop(index=df_infos[df_infos.name == elem].index[1])

# %%
df_infos.to_parquet('infos.parquet')

# %% [markdown]
# ### Join all datasets

# %%
surnames = pd.read_parquet('surnames.parquet')
books = pd.read_parquet('books.parquet')
infos = pd.read_parquet('infos.parquet')

# %%
surnames
# Out:
#                      name                                            surname
# 0           A certain man                                                 []
# 1        Abelar Hightower                                                 []
# 2                  Abelon                                                 []
# 3     Addam of Duskendale                            [\nAddam of Duskendale]
# 4              Addam Frey                                                 []
# ...                   ...                                                ...
# 3674      Zharaq zo Loraq                                  [\nThe Liberator]
# 3675                 Zhea  [Zhea the Barren, Zhea Zorseface, Zhea the Cruel]
# 3676       Zhoe Blanetree                                                 []
# 3677             Zia Frey                                                 []
# 3678                Zollo                                  [\nZollo the Fat]
#
# [3666 rows x 2 columns]

# %%
books
# Out:
#                      name            books_mentioned      books_appearance  \
# 0           A certain man         [A Clash of Kings]                    []
# 1        Abelar Hightower                         []    [The Hedge Knight]
# 2                  Abelon           [Fire and Blood]                    []
# 3     Addam of Duskendale  [The World of Ice & Fire]                    []
# 4              Addam Frey                         []  [The Mystery Knight]
# ...                   ...                        ...                   ...
# 3674      Zharaq zo Loraq     [A Dance with Dragons]                    []
# 3675                 Zhea  [The World of Ice & Fire]                    []
# 3676       Zhoe Blanetree                         []                    []
# 3677             Zia Frey                         []                    []
# 3678                Zollo        [A Feast for Crows]   [A Storm of Swords]
#
#      books_POV
# 0           []
# 1           []
# 2           []
# 3           []
# 4           []
# ...        ...
# 3674        []
# 3675        []
# 3676        []
# 3677        []
# 3678        []
#
# [3666 rows x 4 columns]

# %%
infos
# Out:
#                      name          infobox_name  text_length  rank
# 0           A certain man         A certain man         1254     3
# 1        Abelar Hightower  Ser Abelar Hightower          508     3
# 2                  Abelon    Archmaester Abelon          102     0
# 3     Addam of Duskendale   Addam of Duskendale          175     0
# 4              Addam Frey        Ser Addam Frey          586    14
# ...                   ...                   ...          ...   ...
# 3674      Zharaq zo Loraq       Zharaq zo Loraq          109     1
# 3675                 Zhea                  Zhea         1110     1
# 3676       Zhoe Blanetree        Zhoe Blanetree          269    21
# 3677             Zia Frey              Zia Frey           64    16
# 3678                Zollo         the Fat Zollo         1035     7
#
# [3666 rows x 4 columns]

# %%
df1 = pd.merge(surnames,infos)
df1
# Out:
#                      name                                            surname  \
# 0           A certain man                                                 []
# 1        Abelar Hightower                                                 []
# 2                  Abelon                                                 []
# 3     Addam of Duskendale                            [\nAddam of Duskendale]
# 4              Addam Frey                                                 []
# ...                   ...                                                ...
# 3661      Zharaq zo Loraq                                  [\nThe Liberator]
# 3662                 Zhea  [Zhea the Barren, Zhea Zorseface, Zhea the Cruel]
# 3663       Zhoe Blanetree                                                 []
# 3664             Zia Frey                                                 []
# 3665                Zollo                                  [\nZollo the Fat]
#
#               infobox_name  text_length  rank
# 0            A certain man         1254     3
# 1     Ser Abelar Hightower          508     3
# 2       Archmaester Abelon          102     0
# 3      Addam of Duskendale          175     0
# 4           Ser Addam Frey          586    14
# ...                    ...          ...   ...
# 3661       Zharaq zo Loraq          109     1
# 3662                  Zhea         1110     1
# 3663        Zhoe Blanetree          269    21
# 3664              Zia Frey           64    16
# 3665         the Fat Zollo         1035     7
#
# [3666 rows x 5 columns]

# %%
df2 = pd.merge(df1,books)
df2
# Out:
#                      name                                            surname  \
# 0           A certain man                                                 []
# 1        Abelar Hightower                                                 []
# 2                  Abelon                                                 []
# 3     Addam of Duskendale                            [\nAddam of Duskendale]
# 4              Addam Frey                                                 []
# ...                   ...                                                ...
# 3661      Zharaq zo Loraq                                  [\nThe Liberator]
# 3662                 Zhea  [Zhea the Barren, Zhea Zorseface, Zhea the Cruel]
# 3663       Zhoe Blanetree                                                 []
# 3664             Zia Frey                                                 []
# 3665                Zollo                                  [\nZollo the Fat]
#
#               infobox_name  text_length  rank            books_mentioned  \
# 0            A certain man         1254     3         [A Clash of Kings]
# 1     Ser Abelar Hightower          508     3                         []
# 2       Archmaester Abelon          102     0           [Fire and Blood]
# 3      Addam of Duskendale          175     0  [The World of Ice & Fire]
# 4           Ser Addam Frey          586    14                         []
# ...                    ...          ...   ...                        ...
# 3661       Zharaq zo Loraq          109     1     [A Dance with Dragons]
# 3662                  Zhea         1110     1  [The World of Ice & Fire]
# 3663        Zhoe Blanetree          269    21                         []
# 3664              Zia Frey           64    16                         []
# 3665         the Fat Zollo         1035     7        [A Feast for Crows]
#
#           books_appearance books_POV
# 0                       []        []
# 1       [The Hedge Knight]        []
# 2                       []        []
# 3                       []        []
# 4     [The Mystery Knight]        []
# ...                    ...       ...
# 3661                    []        []
# 3662                    []        []
# 3663                    []        []
# 3664                    []        []
# 3665   [A Storm of Swords]        []
#
# [3666 rows x 8 columns]

# %%
df2.to_parquet('pages.parquet')

# %%
pd.read_parquet('pages.parquet')
# Out:
#                      name                                            surname  \
# 0           A certain man                                                 []
# 1        Abelar Hightower                                                 []
# 2                  Abelon                                                 []
# 3     Addam of Duskendale                            [\nAddam of Duskendale]
# 4              Addam Frey                                                 []
# ...                   ...                                                ...
# 3661      Zharaq zo Loraq                                  [\nThe Liberator]
# 3662                 Zhea  [Zhea the Barren, Zhea Zorseface, Zhea the Cruel]
# 3663       Zhoe Blanetree                                                 []
# 3664             Zia Frey                                                 []
# 3665                Zollo                                  [\nZollo the Fat]
#
#               infobox_name  text_length  rank            books_mentioned  \
# 0            A certain man         1254     3         [A Clash of Kings]
# 1     Ser Abelar Hightower          508     3                         []
# 2       Archmaester Abelon          102     0           [Fire and Blood]
# 3      Addam of Duskendale          175     0  [The World of Ice & Fire]
# 4           Ser Addam Frey          586    14                         []
# ...                    ...          ...   ...                        ...
# 3661       Zharaq zo Loraq          109     1     [A Dance with Dragons]
# 3662                  Zhea         1110     1  [The World of Ice & Fire]
# 3663        Zhoe Blanetree          269    21                         []
# 3664              Zia Frey           64    16                         []
# 3665         the Fat Zollo         1035     7        [A Feast for Crows]
#
#           books_appearance books_POV
# 0                       []        []
# 1       [The Hedge Knight]        []
# 2                       []        []
# 3                       []        []
# 4     [The Mystery Knight]        []
# ...                    ...       ...
# 3661                    []        []
# 3662                    []        []
# 3663                    []        []
# 3664                    []        []
# 3665   [A Storm of Swords]        []
#
# [3666 rows x 8 columns]
